# %% [markdown]
# <a href="https://colab.research.google.com/github/Kur1sutaru/balaio-de-scripts/blob/main/tgfpkmhistogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Replace the file ID with your own
df = pd.read_csv("/content/combinedusergenelists.csv")

# %%
df
# Out:
#     Gene Input Vizgen Gene         Ensemble ID          Transcript  Notes  \
# 0         ACHE        Ache  ENSMUSG00000023328  ENSMUST00000024099    NaN
# 1         ACLY        Acly  ENSMUSG00000020917  ENSMUST00000107389    NaN
# 2       ACSBG1      Acsbg1  ENSMUSG00000032281  ENSMUST00000034822    NaN
# 3      ADCYAP1     Adcyap1  ENSMUSG00000024256  ENSMUST00000234081    NaN
# 4       ADIPOQ      Adipoq  ENSMUSG00000022878  ENSMUST00000023593    NaN
# ..         ...         ...                 ...                 ...    ...
# 505      VAMP2       Vamp2  ENSMUSG00000020894  ENSMUST00000021273    NaN
# 506      VEGFA       Vegfa  ENSMUSG00000023951  ENSMUST00000024747    NaN
# 507        VIP         Vip  ENSMUSG00000019772  ENSMUST00000019906    NaN
# 508      VSTM5       Vstm5  ENSMUSG00000031937  ENSMUST00000034413    NaN
# 509        YY1         Yy1  ENSMUSG00000021264  ENSMUST00000021692    NaN
#
#      Abundance  Target Regions     Type
# ...

# %%
import numpy as np
from google.colab import autoviz
df_8726403681859598687 = autoviz.get_registered_df('df_8726403681859598687')

def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
  from matplotlib import pyplot as plt
  if sort_ascending:
    df = df.sort_values(y).reset_index(drop=True)
  _, ax = plt.subplots(figsize=figsize)
  df[y].plot(kind='line')
  plt.title(y)
  ax.spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = value_plot(df_8726403681859598687, *['Abundance'], **{})
chart
# Out:
# <img src="...">
#         <script></script>

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above)
sns.set(style="darkgrid")
df = df

sns.distplot(df["Abundance"])
plt.show()
# Out:
# <ipython-input-6-4a41079e13cc>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Abundance"])

# %%
## use histplot function
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above)
sns.set(style="darkgrid")
df = df

sns.histplot(df["Abundance"])
plt.show()

# %%
# Custom the inside plot: options are: “scatter” | “reg” | “resid” | “kde” | “hex”
sns.jointplot(x=df["Abundance"], y=df["Abundance"], kind='scatter')
sns.jointplot(x=df["Abundance"], y=df["Abundance"], kind='hex')
sns.jointplot(x=df["Abundance"], y=df["Abundance"], kind='kde')

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt

# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above)
sns.set(style="darkgrid")
sns

sns.histplot(data=df, x="Abundance")
plt.show()
