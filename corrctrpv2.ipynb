# %% [markdown]
# <a href="https://colab.research.google.com/github/Kur1sutaru/balaio-de-scripts/blob/main/corrctrpv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bf00e126-0bb1-45ce-aee4-d4cc22bffeb9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf00e126-0bb1-45ce-aee4-d4cc22bffeb9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving corrzscore.csv to corrzscore.csv

# %%
data = pd.read_csv('corrzscore.csv')

# %%
data
# Out:
#      ccl_name                                 cpd_name  pred_pv_high_conc  \
# 0          EN                               tivantinib             0.5054
# 1          EN           JQ-1:carboplatin (1:1 mol/mol)             0.7782
# 2          EN                       GSK-3 inhibitor IX             0.2751
# 3          EN                                  BRD8899             0.9650
# 4          EN                                SJ-172550             0.9871
# ...       ...                                      ...                ...
# 4704    SW948                                 NSC19630             0.9035
# 4705    SW948                                 GDC-0941             0.1334
# 4706    SW948                 PF-4800567 hydrochloride             0.8473
# 4707    SW948  selumetinib:BRD-A02303741 (4:1 mol/mol)             0.3023
# 4708    SW948                                NSC632839             0.0738
#
#       area_under_curve    zscore  Coefficient   Gene
# ...

# %%
data.corr()
# Out:
#                    pred_pv_high_conc  area_under_curve    zscore  Coefficient
# pred_pv_high_conc           1.000000          0.664276  0.025700     0.145503
# area_under_curve            0.664276          1.000000  0.008508    -0.042900
# zscore                      0.025700          0.008508  1.000000          NaN
# Coefficient                 0.145503         -0.042900       NaN     1.000000

# %%
# delete the column 'ccl_name'
del data['ccl_name']
data
# Out:
#                                      cpd_name  pred_pv_high_conc  \
# 0                                  tivantinib             0.5054
# 1              JQ-1:carboplatin (1:1 mol/mol)             0.7782
# 2                          GSK-3 inhibitor IX             0.2751
# 3                                     BRD8899             0.9650
# 4                                   SJ-172550             0.9871
# ...                                       ...                ...
# 4704                                 NSC19630             0.9035
# 4705                                 GDC-0941             0.1334
# 4706                 PF-4800567 hydrochloride             0.8473
# 4707  selumetinib:BRD-A02303741 (4:1 mol/mol)             0.3023
# 4708                                NSC632839             0.0738
#
#       area_under_curve    zscore  Coefficient   Gene
# 0              11.0660  4.079095      1.42311  POSTN
# 1              14.4710  4.079095      1.36855   ZIC2
# ...

# %%
# delete the column 'cpd_name'
del data['cpd_name']
data
# Out:
#       pred_pv_high_conc  area_under_curve    zscore  Coefficient   Gene
# 0                0.5054           11.0660  4.079095      1.42311  POSTN
# 1                0.7782           14.4710  4.079095      1.36855   ZIC2
# 2                0.2751           12.4360  4.079095      1.08835   ENO2
# 3                0.9650           14.4760  4.079095      0.99817  CRIP1
# 4                0.9871           14.9030  4.079095      0.96403  THOC4
# ...                 ...               ...       ...          ...    ...
# 4704             0.9035           13.5530 -1.001645          NaN    NaN
# 4705             0.1334           10.3660 -1.001645          NaN    NaN
# 4706             0.8473           12.8290 -1.001645          NaN    NaN
# 4707             0.3023            6.2296 -1.001645          NaN    NaN
# 4708             0.0738           12.0630 -1.001645          NaN    NaN
#
# [4709 rows x 5 columns]

# %%
# delete the column 'Gene'
del data['Gene']
data
# Out:
#       pred_pv_high_conc  area_under_curve    zscore  Coefficient
# 0                0.5054           11.0660  4.079095      1.42311
# 1                0.7782           14.4710  4.079095      1.36855
# 2                0.2751           12.4360  4.079095      1.08835
# 3                0.9650           14.4760  4.079095      0.99817
# 4                0.9871           14.9030  4.079095      0.96403
# ...                 ...               ...       ...          ...
# 4704             0.9035           13.5530 -1.001645          NaN
# 4705             0.1334           10.3660 -1.001645          NaN
# 4706             0.8473           12.8290 -1.001645          NaN
# 4707             0.3023            6.2296 -1.001645          NaN
# 4708             0.0738           12.0630 -1.001645          NaN
#
# [4709 rows x 4 columns]

# %%
# library & dataset
import seaborn as sns
df = data


# Basic correlogram
sns.pairplot(data)

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Default heatmap
p1 = sns.heatmap(data)
